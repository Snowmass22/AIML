# %%
import numpy as np

# %%
#linear regression with gradient descent
class LinearRegression:
    def __init__(self,learning_rate=0.01,n_iter=1000):
        self.bais=None
        self.weights=None
        self.lr=learning_rate
        self.n_iter=n_iter
        
    def fit(self,x,y):#x_train,y_train
        m,n=x.shape#(number of samples,number of features)

        #step1 initilize
        self.bais=0
        self.weights=np.zeros(n)

        #gradient descent
        for i in range(self.n_iter):
            #step 2 calc y_pred
            y_pred=self.bais+np.dot(x,self.weights)

            #step3 calc gradient
            db=(1/m)*np.sum(y_pred-y)
            dw=(1/m)*np.dot(x.T,(y_pred-y))

            #step 4 convergence theorem
            self.bais=self.bais-self.lr*db
            self.weights-=self.lr*dw
            
        

    def predict(self,x):
        y_pred=self.bais+np.dot(x,self.weights)
        return y_pred

# %%
x=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,5,6,8])

model=LinearRegression()
model.fit(x,y)
y_pred=model.predict(x)
print(y_pred)
# Out:
# [2.14902128 3.56855098 4.98808069 6.40761039 7.82714009]

# %%
#linear regression using ols

class LinearRegressionOLS:
    def __init__(self):
        self.bias=None
        self.weights=None

    def fit(self,x,y):
        m,n=x.shape

        x_b=np.c_[np.ones((m,1)),x]

        theta=np.linalg.inv(x_b.T@x_b.T@y)

        self.bias=theta[0]
        self.weights=theta[1:]
    def predict():
        y_pred=self.bias+np.dot(x,self.weights)
        return y_pred

# %%
x=np.array([[1],[2],[3],[4],[5]])
y=np.array([2,4,5,6,8])

model=LinearRegressionOLS()
model.fit(x,y)
y_pred=model.predict(x)
print(y_pred)
print(model.bias)
print(model.weights)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 5
#       2 y=np.array([2,4,5,6,8])
#       4 model=LinearRegressionOLS()
# ----> 5 model.fit(x,y)
#       6 y_pred=model.predict(x)
#       7 print(y_pred)
#
# Cell In[27], line 13, in LinearRegressionOLS.fit(self, x, y)
#       9 m,n=x.shape
#      11 x_b=np.c_[np.ones((m,1)),x]
# ---> 13 theta=np.linalg.inv(x_b.T@x_b.T@y)
#      15 self.bias=theta[0]
#      16 self.weights=theta[1:]
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 5)
