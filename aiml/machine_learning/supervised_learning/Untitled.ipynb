# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("practo_doctors_final_delhi.csv")
df.isnull().values.any()
# Out:
# np.True_

# %%
df=df.fillna("NAN")

# %%
df.isnull().values.any()
# Out:
# np.False_

# %%
df.head()
# Out:
#                               full_name  \
# 0                     Dr. Aashia Rumman
# 1                      Dr. Sachin Rawat
# 2  Dr. Kriti Tiwari   (Physiotherapist)
# 3                     Dr. Ankita Thakur
# 4                  Dr. Aakanksha Bhatia
#
#                                       specialization  \
# 0                                       Gynecologist
# 1  General Physician, MBBS(Unverified)Practo does...
# 2  Geriatric Physiotherapist, Physiotherapist, Cl...
# 3                                       Pediatrician
# 4                         Pain Management Specialist
#
#                          qualification experience   location  \
# 0  MS - Obstetrics & Gynaecology, MBBS   10 years      Delhi
# 1                                 MBBS    5 years  New-Delhi
# 2                             BPTh/BPT    4 years  New-Delhi
# 3                MBBS, MD - Pediatrics    8 years      Delhi
# 4           MD - Anaesthesiology, MBBS    5 years      Delhi
#
# ...

# %%
df.to_excel("practo_doctors_delhi.xlsx", index=False)
